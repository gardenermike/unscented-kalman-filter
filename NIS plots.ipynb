# %%
import matplotlib.pyplot as plt
import pandas

# %matplotlib inline

# %%
data = pandas.read_csv("radar_nis.csv", header=None)
data.columns = ["Radar NIS"]
data["χ2"] = 7.815
ax = data.plot()

# %%
data = pandas.read_csv('laser_nis.csv', header=None)
data.columns = ["Laser NIS"]
data["χ2"] = 5.991
data.plot(legend=False)
